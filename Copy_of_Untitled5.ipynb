# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandli07goyal/Cantilever/blob/main/Copy_of_Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
#loading the dataset to a Pandas DataFrame
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
#1st five rows of the dataset
credit_card_data.head()
# Out:
#           "Time"        V1        V2        V3        V4        V5        V6  \
# 0              0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1              0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2              1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3              1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4              2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928
# 1 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575
# 4  0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3  0.647376 -0.221929  0.062723  0.061458  123.50    0.0
# 4 -0.206010  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
credit_card_data.tail()
# Out:
#               "Time"        V1        V2        V3        V4        V5  \
# 55757          47109  1.274153 -0.211245 -0.668608 -0.533112  1.688340
# 55758          47109 -2.211229  2.325129 -0.111247 -0.161217  0.507490
# 55759          47110 -1.353398  0.266161  0.900867  1.399121  0.907504
# 55760          47111  1.294696 -0.892700  0.253519 -0.575688 -1.065250
# 55761          47111 -2.433000 -2.168777  1.833636 -3.008002       NaN
#
#              V6        V7        V8        V9  ...       V21       V22  \
# 55757  3.533536 -0.914970  0.931972  0.244693  ... -0.137736 -0.549644
# 55758 -0.351142  0.428957  0.464533 -0.863321  ...  0.059256 -0.083281
# 55759  0.125401 -0.096627  0.575556 -0.620287  ...  0.069243 -0.010071
# 55760 -0.167557 -0.839139  0.258070 -0.282317  ...  0.100555  0.212194
# 55761       NaN       NaN       NaN       NaN  ...       NaN       NaN
#
#             V23       V24       V25       V26       V27       V28  Amount  \
# 55757  0.054104  1.011011  0.319599  0.228477 -0.004502  0.020288    8.99
# 55758 -0.255582 -0.410633  0.461623  0.338443 -1.089014 -0.216520    0.76
# 55759 -0.265363 -0.732971  0.267555 -0.147605  0.037950 -0.099563   23.96
# 55760 -0.057230 -0.015297  0.469587 -0.123923 -0.004968 -0.010185   20.95
# 55761       NaN       NaN       NaN       NaN       NaN       NaN     NaN
#
#        Class
# 55757    0.0
# 55758    0.0
# 55759    0.0
# 55760    0.0
# 55761    NaN
#
# [5 rows x 31 columns]

# %%
#dataset informations
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55762 entries, 0 to 55761
# Data columns (total 31 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0          "Time"  55762 non-null  int64
#  1   V1             55762 non-null  float64
#  2   V2             55762 non-null  float64
#  3   V3             55762 non-null  float64
#  4   V4             55762 non-null  float64
#  5   V5             55761 non-null  float64
#  6   V6             55761 non-null  float64
#  7   V7             55761 non-null  float64
#  8   V8             55761 non-null  float64
#  9   V9             55761 non-null  float64
#  10  V10            55761 non-null  float64
#  11  V11            55761 non-null  float64
#  12  V12            55761 non-null  float64
#  13  V13            55761 non-null  float64
#  14  V14            55761 non-null  float64
#  15  V15            55761 non-null  float64
#  16  V16            55761 non-null  float64
#  17  V17            55761 non-null  float64
#  18  V18            55761 non-null  float64
#  19  V19            55761 non-null  float64
#  20  V20            55761 non-null  float64
#  21  V21            55761 non-null  float64
#  22  V22            55761 non-null  float64
#  23  V23            55761 non-null  float64
#  24  V24            55761 non-null  float64
#  25  V25            55761 non-null  float64
#  26  V26            55761 non-null  float64
#  27  V27            55761 non-null  float64
#  28  V28            55761 non-null  float64
#  29  Amount         55761 non-null  float64
#  30  Class          55761 non-null  float64
# dtypes: float64(30), int64(1)
# memory usage: 13.2 MB

# %%
#checking the number of missing values in each column
credit_card_data.isnull().sum()
# Out:
#        "Time"    0
# V1               0
# V2               0
# V3               0
# V4               0
# V5               1
# V6               1
# V7               1
# V8               1
# V9               1
# V10              1
# V11              1
# V12              1
# V13              1
# V14              1
# V15              1
# V16              1
# V17              1
# V18              1
# V19              1
# V20              1
# V21              1
# V22              1
# V23              1
# V24              1
# V25              1
# V26              1
# V27              1
# V28              1
# Amount           1
# Class            1
# dtype: int64

# %%
#distribution of legit transactions & fraudulent transactions
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    55605
# 1.0      156
# Name: count, dtype: int64

# %% [markdown]
# The dataset is highly unbalanced

# %% [markdown]
# 0 --> Normal Transaction

# %% [markdown]
# 1 --> fraudulent Transaction

# %%
#seperating the data for analysis
legit = credit_card_data[credit_card_data.Class ==0]
fraud = credit_card_data[credit_card_data.Class ==1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (55605, 31)
# (156, 31)

# %%
#statistical measures of the data
legit.Amount.describe()
# Out:
# count    55605.000000
# mean        94.711583
# std        256.791256
# min          0.000000
# 25%          7.680000
# 50%         25.840000
# 75%         86.950000
# max      12910.930000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     156.000000
# mean       95.758013
# std       228.178528
# min         0.000000
# 25%         1.000000
# 50%         4.930000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
#compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#               "Time"        V1        V2        V3        V4        V5  \
# Class
# 0.0     30663.205071 -0.222555 -0.019313  0.721247  0.159991 -0.243918
# 1.0     27835.794872 -7.345427  5.255872 -9.922599  5.709553 -5.426307
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.108086 -0.096763  0.045577  0.091726  ...  0.046514 -0.031208
# 1.0   -2.204159 -7.736462  3.560034 -3.453697  ...  0.449731  0.881689
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.106683 -0.038540  0.007594  0.134673  0.020445  0.002063  0.004017
# 1.0   -0.211806 -0.275513 -0.088146  0.239724  0.127377  0.580843  0.031086
#
#           Amount
# Class
# 0.0    94.711583
# 1.0    95.758013
#
# [2 rows x 30 columns]

# %% [markdown]
# Under sampling

# %% [markdown]
# Build a sample dataset containing similar distribution of normal transactions and Fraudulent Transactions

# %% [markdown]
# Number of fraudulent Transactions --> 492

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# Concatenating two DataFrames

# %%
new_dataset = pd.concat([legit_sample, fraud], axis = 0)

# %%
new_dataset.head()
# Out:
#               "Time"         V1        V2        V3        V4        V5  \
# 15346          26737   1.297540 -0.006853 -0.694704 -0.201115  0.350886
# 40318          40190 -10.717152 -9.765205 -0.149089  0.869825  2.147759
# 24473          33251  -0.961996  1.086766  1.321469 -1.391511 -0.311414
# 47242          43146   1.235479  0.506458 -0.125402  1.050305  0.286686
# 55692          47070   0.635317 -2.511961  0.106618 -0.896842 -1.888700
#
#              V6        V7        V8        V9  ...       V21       V22  \
# 15346 -0.561549  0.432682 -0.264949 -0.003581  ... -0.442580 -1.448268
# 40318 -2.414274 -0.474343 -0.331346  0.183203  ... -1.976716  2.056766
# 24473 -1.122731  0.677736 -0.205684  0.897964  ... -0.256471 -0.340501
# 47242 -0.707413  0.521581 -0.257171 -0.389678  ...  0.038376  0.239374
# 55692 -0.140361 -0.493106 -0.239722 -1.518217  ... -0.267572 -1.236522
#
#             V23       V24       V25       V26       V27       V28  Amount  \
# 15346 -0.070499 -0.985941  0.366371  0.785455 -0.121759 -0.004920   64.40
# 40318  5.528764  0.393536  2.338089  0.286455  2.250631 -0.057115  240.00
# 24473 -0.024630  0.396069 -0.140852  0.710020  0.321698  0.041166    7.68
# 47242 -0.123679  0.114424  0.803978 -0.269055  0.013295  0.008966    1.00
# 55692 -0.300662 -0.138847  0.139602 -0.445372 -0.026946  0.103515  469.70
#
#        Class
# 15346    0.0
# 40318    0.0
# 24473    0.0
# 47242    0.0
# 55692    0.0
#
# [5 rows x 31 columns]

# %%
new_dataset.tail()
# Out:
#               "Time"        V1        V2        V3        V4        V5  \
# 52521          45501  1.001992  0.047938 -0.349002  1.493958  0.186939
# 52584          45541 -1.519244  2.308492 -1.503599  2.064101 -1.000845
# 53591          46057 -1.309441  1.786495 -1.371070  1.214335 -0.336642
# 53794          46149 -1.346509  2.132431 -1.854355  2.116998 -1.070378
# 55401          46925 -0.481531  1.059542  0.647117  0.905586  0.819368
#
#              V6        V7        V8        V9  ...       V21       V22  \
# 52521  0.190966 -0.001112  0.147140  0.580415  ... -0.334417 -1.014315
# 52584 -1.016897 -2.059731 -0.275166 -1.562206  ...  1.307871  0.102826
# 53591 -1.390120 -1.709109  0.667748 -1.699809  ...  0.533521 -0.022180
# 53794 -1.092671 -2.230986  1.036425 -1.895516  ...  0.609508  0.202874
# 55401 -0.091184  0.504135  0.161064 -0.765054  ...  0.070633  0.192491
#
#             V23       V24       V25       V26       V27       V28  Amount  \
# 52521 -0.128427 -0.946242  0.456090 -0.453206  0.046627  0.064698  105.99
# 52584 -0.017746  0.149696 -0.096602 -0.369115 -0.019244 -0.208319    1.00
# 53591 -0.299556 -0.226416  0.364360 -0.475102  0.571426  0.293426    1.00
# 53794 -0.060791 -0.186733 -0.017401 -0.283751  0.395451  0.233139    1.00
# 55401 -0.174659 -0.438908  0.239259 -0.217823 -0.072852  0.010463    1.00
#
#        Class
# 52521    1.0
# 52584    1.0
# 53591    1.0
# 53794    1.0
# 55401    1.0
#
# [5 rows x 31 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0    156
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#               "Time"        V1        V2        V3        V4        V5  \
# Class
# 0.0     31059.703252 -0.230605 -0.149749  0.666187  0.136470 -0.260403
# 1.0     27835.794872 -7.345427  5.255872 -9.922599  5.709553 -5.426307
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.103741 -0.025433  0.096934  0.051075  ...  0.118849 -0.062282
# 1.0   -2.204159 -7.736462  3.560034 -3.453697  ...  0.449731  0.881689
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.113425 -0.033739  0.071977  0.143570  0.028653  0.000428  0.003832
# 1.0   -0.211806 -0.275513 -0.088146  0.239724  0.127377  0.580843  0.031086
#
#            Amount
# Class
# 0.0    118.310203
# 1.0     95.758013
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the data into Features & Targets

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#               "Time"         V1        V2        V3        V4        V5  \
# 15346          26737   1.297540 -0.006853 -0.694704 -0.201115  0.350886
# 40318          40190 -10.717152 -9.765205 -0.149089  0.869825  2.147759
# 24473          33251  -0.961996  1.086766  1.321469 -1.391511 -0.311414
# 47242          43146   1.235479  0.506458 -0.125402  1.050305  0.286686
# 55692          47070   0.635317 -2.511961  0.106618 -0.896842 -1.888700
# ...              ...        ...       ...       ...       ...       ...
# 52521          45501   1.001992  0.047938 -0.349002  1.493958  0.186939
# 52584          45541  -1.519244  2.308492 -1.503599  2.064101 -1.000845
# 53591          46057  -1.309441  1.786495 -1.371070  1.214335 -0.336642
# 53794          46149  -1.346509  2.132431 -1.854355  2.116998 -1.070378
# 55401          46925  -0.481531  1.059542  0.647117  0.905586  0.819368
#
#              V6        V7        V8        V9  ...       V20       V21  \
# 15346 -0.561549  0.432682 -0.264949 -0.003581  ...  0.069635 -0.442580
# 40318 -2.414274 -0.474343 -0.331346  0.183203  ... -6.276043 -1.976716
# 24473 -1.122731  0.677736 -0.205684  0.897964  ...  0.429072 -0.256471
# 47242 -0.707413  0.521581 -0.257171 -0.389678  ... -0.142803  0.038376
# 55692 -0.140361 -0.493106 -0.239722 -1.518217  ...  0.658738 -0.267572
# ...         ...       ...       ...       ...  ...       ...       ...
# 52521  0.190966 -0.001112  0.147140  0.580415  ...  0.016004 -0.334417
# 52584 -1.016897 -2.059731 -0.275166 -1.562206  ...  0.175019  1.307871
# 53591 -1.390120 -1.709109  0.667748 -1.699809  ...  0.253464  0.533521
# 53794 -1.092671 -2.230986  1.036425 -1.895516  ...  0.221919  0.609508
# 55401 -0.091184  0.504135  0.161064 -0.765054  ... -0.042515  0.070633
#
#             V22       V23       V24       V25       V26       V27       V28  \
# 15346 -1.448268 -0.070499 -0.985941  0.366371  0.785455 -0.121759 -0.004920
# 40318  2.056766  5.528764  0.393536  2.338089  0.286455  2.250631 -0.057115
# 24473 -0.340501 -0.024630  0.396069 -0.140852  0.710020  0.321698  0.041166
# 47242  0.239374 -0.123679  0.114424  0.803978 -0.269055  0.013295  0.008966
# 55692 -1.236522 -0.300662 -0.138847  0.139602 -0.445372 -0.026946  0.103515
# ...         ...       ...       ...       ...       ...       ...       ...
# 52521 -1.014315 -0.128427 -0.946242  0.456090 -0.453206  0.046627  0.064698
# 52584  0.102826 -0.017746  0.149696 -0.096602 -0.369115 -0.019244 -0.208319
# 53591 -0.022180 -0.299556 -0.226416  0.364360 -0.475102  0.571426  0.293426
# 53794  0.202874 -0.060791 -0.186733 -0.017401 -0.283751  0.395451  0.233139
# 55401  0.192491 -0.174659 -0.438908  0.239259 -0.217823 -0.072852  0.010463
#
#        Amount
# 15346   64.40
# 40318  240.00
# 24473    7.68
# 47242    1.00
# 55692  469.70
# ...       ...
# 52521  105.99
# 52584    1.00
# 53591    1.00
# 53794    1.00
# 55401    1.00
#
# [648 rows x 30 columns]

# %%
print(Y)
# Out:
# 15346    0.0
# 40318    0.0
# 24473    0.0
# 47242    0.0
# 55692    0.0
#         ...
# 52521    1.0
# 52584    1.0
# 53591    1.0
# 53794    1.0
# 55401    1.0
# Name: Class, Length: 648, dtype: float64

# %% [markdown]
# Split the data into Training Data & Testing Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (648, 30) (518, 30) (130, 30)

# %% [markdown]
# Model Training

# %% [markdown]
# Logistic Regression

# %%
model = LogisticRegression()

# %%
# training the Logistic Regression
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
#accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Trainig data : ', training_data_accuracy)
# Out:
# Accuracy on Trainig data :  0.972972972972973

# %%
#accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.9769230769230769
